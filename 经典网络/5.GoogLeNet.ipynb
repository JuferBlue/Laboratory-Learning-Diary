# %% [markdown]
# ## GoogLeNet

# %%
# 导入相关的包
import torch
import torchvision
from torch import nn
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
import os
import torch.nn.functional as F
# 指定训练设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# 对图片的预处理
transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((224, 224)),
    torchvision.transforms.ToTensor()
])

# 导入数据集
train_data = torchvision.datasets.CIFAR10(root='../数据集/cifar10', train=True, transform=transform, download=True)
test_data = torchvision.datasets.CIFAR10(root='../数据集/cifar10', train=False, transform=transform, download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# 保存数据集的长度
train_data_size = len(train_data)
test_data_size = len(test_data)
print("训练数据集的长度为：{}".format(train_data_size))
print("测试数据集的长度为：{}".format(test_data_size))
# Out:
# 训练数据集的长度为：50000
# 测试数据集的长度为：10000

# %%
# 创建数据加载器
train_dataloader = DataLoader(train_data, batch_size=64)
test_dataloader = DataLoader(test_data, batch_size=64)

# %%
# 定义Inception模块
class Inception(nn.Module):
    # c1,c2,c3,c4是每条路径的输出通道数
    def __init__(self, in_channels, c1, c2, c3, c4,**kwargs):
        super(Inception, self).__init__()
        # 路径1：1x1卷积
        self.path1 = nn.Conv2d(in_channels, c1, kernel_size=1)
        # 路径2：1x1卷积+3x3卷积
        self.path2_1 = nn.Conv2d(in_channels, c2[0], kernel_size=1)
        self.path2_2 = nn.Conv2d(c2[0], c2[1], kernel_size=3, padding=1)
        # 路径3：1x1卷积+5x5卷积
        self.path3_1 = nn.Conv2d(in_channels, c3[0], kernel_size=1)
        self.path3_2 = nn.Conv2d(c3[0], c3[1], kernel_size=5, padding=2)
        # 路径4：3x3最大池化+1x1卷积
        self.path4_1 = nn.MaxPool2d(kernel_size=3, stride=1, padding=1)
        self.path4_2 = nn.Conv2d(in_channels, c4, kernel_size=1)
    
    def forward(self, x):
        path1 = F.relu(self.path1(x))  # 添加F.relu进行激活
        path2 = F.relu(self.path2_2(F.relu(self.path2_1(x))))  # 嵌套路径需要嵌套激活
        path3 = F.relu(self.path3_2(F.relu(self.path3_1(x))))
        path4 = F.relu(self.path4_2(self.path4_1(x)))  # 注意：path4_1是池化层，通常不跟激活函数
        return torch.cat([path1, path2, path3, path4], dim=1)

# %%
# 实现每一个stage
b1 = nn.Sequential(
    nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3),
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
)
b2 = nn.Sequential(
    nn.Conv2d(64, 64, kernel_size=1),
    nn.ReLU(),
    nn.Conv2d(64, 192, kernel_size=3, padding=1),
    nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
)

b3 = nn.Sequential(
    Inception(192, 64, (96, 128), (16, 32), 32),
    Inception(256, 128, (128, 192), (32, 96), 64),
    nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
)

b4 = nn.Sequential(
    Inception(480, 192, (96, 208), (16, 48), 64),
    Inception(512, 160, (112, 224), (24, 64), 64),
    Inception(512, 128, (128, 256), (24, 64), 64),
    Inception(512, 112, (144, 288), (32, 64), 64),
    Inception(528, 256, (160, 320), (32, 128), 128),
    nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
)
b5 = nn.Sequential(
    Inception(832, 256, (160, 320), (32, 128), 128),
    Inception(832, 384, (192, 384), (48, 128), 128),
    nn.AdaptiveAvgPool2d((1, 1)),
    nn.Flatten()
)
googlenet = nn.Sequential(b1, b2, b3, b4, b5, nn.Linear(1024, 10))
googlenet.to(device)
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     (0): Inception(
#       (path1): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       (path1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     (0): Inception(
#       (path1): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       (path1): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception(
#       (path1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception(
#       (path1): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception(
#       (path1): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     (0): Inception(
#       (path1): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       (path1): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(output_size=(1, 1))
#     (3): Flatten(start_dim=1, end_dim=-1)
#   )
#   (5): Linear(in_features=1024, out_features=10, bias=True)
# )

# %%
# 观察每一层输出的形状
x = torch.randn(size=(1, 3, 224, 224), device=device)
for blk in googlenet:
    x = blk(x)
    print(blk.__class__.__name__, 'output shape: \t\t', x.shape)
# Out:
# Sequential output shape: 		 torch.Size([1, 64, 56, 56])
# Sequential output shape: 		 torch.Size([1, 192, 28, 28])
# Sequential output shape: 		 torch.Size([1, 480, 14, 14])
# Sequential output shape: 		 torch.Size([1, 832, 7, 7])
# Sequential output shape: 		 torch.Size([1, 1024])
# Linear output shape: 		 torch.Size([1, 10])

# %%
# 初始化模型参数
def init_weights(m):
    if type(m) == nn.Linear or type(m) == nn.Conv2d:
        torch.nn.init.xavier_uniform_(m.weight)
googlenet.apply(init_weights)
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (1): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (2): Sequential(
#     (0): Inception(
#       (path1): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(192, 96, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(192, 16, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       (path1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(128, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(32, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (3): Sequential(
#     (0): Inception(
#       (path1): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(480, 96, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(96, 208, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(480, 16, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(16, 48, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(480, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       (path1): Conv2d(512, 160, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(112, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Inception(
#       (path1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(512, 24, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(24, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Inception(
#       (path1): Conv2d(512, 112, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(512, 144, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(144, 288, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Inception(
#       (path1): Conv2d(528, 256, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(528, 160, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(528, 32, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(528, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (4): Sequential(
#     (0): Inception(
#       (path1): Conv2d(832, 256, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(832, 160, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(160, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(832, 32, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(32, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Inception(
#       (path1): Conv2d(832, 384, kernel_size=(1, 1), stride=(1, 1))
#       (path2_1): Conv2d(832, 192, kernel_size=(1, 1), stride=(1, 1))
#       (path2_2): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (path3_1): Conv2d(832, 48, kernel_size=(1, 1), stride=(1, 1))
#       (path3_2): Conv2d(48, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (path4_1): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#       (path4_2): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): AdaptiveAvgPool2d(output_size=(1, 1))
#     (3): Flatten(start_dim=1, end_dim=-1)
#   )
#   (5): Linear(in_features=1024, out_features=10, bias=True)
# )

# %%
# 损失函数
loss_fn = nn.CrossEntropyLoss()
loss_fn = loss_fn.to(device)

# 优化器
learning_rate = 0.1
optimizer = torch.optim.SGD(googlenet.parameters(), lr=learning_rate)

# 设置训练网络的一些参数
# 记录训练的次数
total_train_step = 0
# 记录测试的次数
total_test_step = 0

# 设置训练网络的循环次数
epoch = 30

# %%
# 开始训练
for i in range(epoch):
    # 训练过程
    print("------第{}轮训练开始------".format(i+1))
    googlenet.train()
    for data in train_dataloader:
        imgs, targets = data
        imgs = imgs.to(device)
        targets = targets.to(device)
        output = googlenet(imgs)
        loss = loss_fn(output, targets)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_train_step += 1
        if total_train_step % 100 == 0:
            print("训练次数：{}，loss：{}".format(total_train_step, loss.item()))
    
    # 测试过程
    googlenet.eval()
    with torch.no_grad():
        total_test_loss = 0
        total_accuracy = 0
        for data in test_dataloader:
            imgs, targets = data
            imgs = imgs.to(device)
            targets = targets.to(device)
            output = googlenet(imgs)
            loss = loss_fn(output, targets)
            total_test_loss += loss.item()
            accuracy = (output.argmax(1) == targets).sum()
            total_accuracy += accuracy.item()
            total_test_step += 1
            
    # 输出一个轮次的信息
    print(f"整体测试集上的loss:{total_test_loss}")
    print(f"整体测试集上的正确率:{total_accuracy/test_data_size}")
    total_test_step += 1
    
    # 创建文件夹用来保存模型
    dir_path = os.path.join(".", "模型保存", "5-GoogLeNet")
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
    # 保存每一轮的模型
    torch.save(googlenet.state_dict(), f"./模型保存/5-GoogLeNet/googlenet{i}.pth")
    print("模型保存成功")
# Out:
# ------第1轮训练开始------
# 训练次数：100，loss：2.304870843887329
# 训练次数：200，loss：2.275134801864624
# 训练次数：300，loss：2.2567343711853027
# 训练次数：400，loss：2.222177505493164
# 训练次数：500，loss：2.369554281234741
# 训练次数：600，loss：2.109814405441284
# 训练次数：700，loss：2.095111131668091
# 整体测试集上的loss:336.39897334575653
# 整体测试集上的正确率:0.1828
# 模型保存成功
# ------第2轮训练开始------
# 训练次数：800，loss：1.8835328817367554
# 训练次数：900，loss：1.9614663124084473
# 训练次数：1000，loss：1.9049007892608643
# 训练次数：1100，loss：1.898341417312622
# 训练次数：1200，loss：1.85712730884552
# 训练次数：1300，loss：1.8609927892684937
# 训练次数：1400，loss：1.7897299528121948
# 训练次数：1500，loss：1.8533904552459717
# 整体测试集上的loss:303.028636097908
# 整体测试集上的正确率:0.2652
# 模型保存成功
# ------第3轮训练开始------
# 训练次数：1600，loss：1.8246123790740967
# 训练次数：1700，loss：1.6848539113998413
# 训练次数：1800，loss：1.95746910572052
# 训练次数：1900，loss：1.8480695486068726
# 训练次数：2000，loss：1.9246047735214233
# 训练次数：2100，loss：1.443303108215332
# 训练次数：2200，loss：1.4302682876586914
# 训练次数：2300，loss：1.5061304569244385
# 整体测试集上的loss:298.95182967185974
# 整体测试集上的正确率:0.2676
# 模型保存成功
# ------第4轮训练开始------
# 训练次数：2400，loss：1.7532322406768799
# 训练次数：2500，loss：1.5608158111572266
# 训练次数：2600，loss：1.7866544723510742
# 训练次数：2700，loss：1.5498374700546265
# 训练次数：2800，loss：1.6439480781555176
# 训练次数：2900，loss：1.6364645957946777
# 训练次数：3000，loss：1.2512564659118652
# 训练次数：3100，loss：1.465688943862915
# 整体测试集上的loss:282.15793228149414
# 整体测试集上的正确率:0.3385
# 模型保存成功
# ------第5轮训练开始------
# 训练次数：3200，loss：1.3100228309631348
# 训练次数：3300，loss：1.490134596824646
# 训练次数：3400，loss：1.3034112453460693
# 训练次数：3500，loss：1.5237112045288086
# 训练次数：3600，loss：1.3273285627365112
# 训练次数：3700，loss：1.2744128704071045
# 训练次数：3800，loss：1.318538784980774
# 训练次数：3900，loss：1.273184895515442
# 整体测试集上的loss:304.06041646003723
# 整体测试集上的正确率:0.3655
# 模型保存成功
# ------第6轮训练开始------
# 训练次数：4000，loss：1.0833323001861572
# 训练次数：4100，loss：1.3756879568099976
# 训练次数：4200，loss：1.452715516090393
# 训练次数：4300，loss：1.157086730003357
# 训练次数：4400，loss：0.9949501156806946
# 训练次数：4500，loss：1.3693424463272095
# 训练次数：4600，loss：1.2731595039367676
# 整体测试集上的loss:275.91612899303436
# 整体测试集上的正确率:0.4239
# 模型保存成功
# ------第7轮训练开始------
# 训练次数：4700，loss：1.0435513257980347
# 训练次数：4800，loss：1.257219672203064
# 训练次数：4900，loss：1.405632495880127
# 训练次数：5000，loss：1.2665542364120483
# 训练次数：5100，loss：0.9656573534011841
# 训练次数：5200，loss：1.0147974491119385
# 训练次数：5300，loss：0.85474693775177
# 训练次数：5400，loss：1.024406909942627
# 整体测试集上的loss:261.82741248607635
# 整体测试集上的正确率:0.4731
# 模型保存成功
# ------第8轮训练开始------
# 训练次数：5500，loss：0.946668267250061
# 训练次数：5600，loss：0.8966548442840576
# 训练次数：5700，loss：0.9833106994628906
# 训练次数：5800，loss：0.7960652709007263
# 训练次数：5900，loss：0.9441741704940796
# 训练次数：6000，loss：1.3773194551467896
# 训练次数：6100，loss：0.8481749296188354
# 训练次数：6200，loss：0.7484844326972961
# 整体测试集上的loss:271.63941860198975
# 整体测试集上的正确率:0.4839
# 模型保存成功
# ------第9轮训练开始------
# 训练次数：6300，loss：1.2985233068466187
# 训练次数：6400，loss：0.8706989884376526
# 训练次数：6500，loss：1.119430661201477
# 训练次数：6600，loss：0.7734783291816711
# 训练次数：6700，loss：0.8157205581665039
# 训练次数：6800，loss：0.7969045042991638
# 训练次数：6900，loss：0.7486449480056763
# 训练次数：7000，loss：0.6292432546615601
# 整体测试集上的loss:259.61029279232025
# 整体测试集上的正确率:0.4913
# 模型保存成功
# ------第10轮训练开始------
# 训练次数：7100，loss：0.6371159553527832
# 训练次数：7200，loss：0.7114130258560181
# 训练次数：7300，loss：0.6236596703529358
# 训练次数：7400，loss：0.6323435306549072
# 训练次数：7500，loss：0.6101821660995483
# 训练次数：7600，loss：1.0009256601333618
# 训练次数：7700，loss：0.5174461603164673
# 训练次数：7800，loss：0.8314998745918274
# 整体测试集上的loss:218.86474406719208
# 整体测试集上的正确率:0.5676
# 模型保存成功
# ------第11轮训练开始------
# 训练次数：7900，loss：1.1033036708831787
# 训练次数：8000，loss：0.708800196647644
# 训练次数：8100，loss：0.6438999772071838
# 训练次数：8200，loss：0.9928959608078003
# 训练次数：8300，loss：1.322698712348938
# 训练次数：8400，loss：0.8507179617881775
# 训练次数：8500，loss：0.7957022190093994
# 训练次数：8600，loss：0.5392093062400818
# 整体测试集上的loss:204.34812158346176
# 整体测试集上的正确率:0.5983
# 模型保存成功
# ------第12轮训练开始------
# 训练次数：8700，loss：0.7217500805854797
# 训练次数：8800，loss：0.643255352973938
# 训练次数：8900，loss：0.6751236915588379
# 训练次数：9000，loss：0.9793292284011841
# 训练次数：9100，loss：0.663163423538208
# 训练次数：9200，loss：0.9437569379806519
# 训练次数：9300，loss：0.6982809901237488
# 整体测试集上的loss:173.44884991645813
# 整体测试集上的正确率:0.6416
# 模型保存成功
# ------第13轮训练开始------
# 训练次数：9400，loss：0.37994691729545593
# 训练次数：9500，loss：0.7623311877250671
# 训练次数：9600，loss：0.6161352396011353
# 训练次数：9700，loss：0.5739827752113342
# 训练次数：9800，loss：0.623640775680542
# 训练次数：9900，loss：0.517081618309021
# 训练次数：10000，loss：0.6059157252311707
# 训练次数：10100，loss：0.5962516069412231
# 整体测试集上的loss:160.11155125498772
# 整体测试集上的正确率:0.6888
# 模型保存成功
# ------第14轮训练开始------
# 训练次数：10200，loss：0.45934364199638367
# 训练次数：10300，loss：0.43874210119247437
# 训练次数：10400，loss：0.7959503531455994
# 训练次数：10500，loss：0.6663129329681396
# 训练次数：10600，loss：0.43427422642707825
# 训练次数：10700，loss：0.2943883240222931
# 训练次数：10800，loss：0.6193169951438904
# 训练次数：10900，loss：0.32294708490371704
# 整体测试集上的loss:142.40357366204262
# 整体测试集上的正确率:0.7185
# 模型保存成功
# ------第15轮训练开始------
# 训练次数：11000，loss：0.484794557094574
# 训练次数：11100，loss：0.28155818581581116
# 训练次数：11200，loss：0.40457090735435486
# 训练次数：11300，loss：0.5901252627372742
# 训练次数：11400，loss：0.5461912155151367
# 训练次数：11500，loss：0.5825125575065613
# 训练次数：11600，loss：0.5560935735702515
# 训练次数：11700，loss：0.5322669148445129
# 整体测试集上的loss:136.40502679347992
# 整体测试集上的正确率:0.7207
# 模型保存成功
# ------第16轮训练开始------
# 训练次数：11800，loss：0.5193737149238586
# 训练次数：11900，loss：0.25158533453941345
# 训练次数：12000，loss：0.29626524448394775
# 训练次数：12100，loss：0.43536314368247986
# 训练次数：12200，loss：0.3204439878463745
# 训练次数：12300，loss：0.43537643551826477
# 训练次数：12400，loss：0.7677338719367981
# 训练次数：12500，loss：0.23136256635189056
# 整体测试集上的loss:132.31496185064316
# 整体测试集上的正确率:0.7508
# 模型保存成功
# ------第17轮训练开始------
# 训练次数：12600，loss：0.4697248041629791
# 训练次数：12700，loss：0.6337330937385559
# 训练次数：12800，loss：0.21937702596187592
# 训练次数：12900，loss：0.43382129073143005
# 训练次数：13000，loss：0.37936487793922424
# 训练次数：13100，loss：0.29755058884620667
# 训练次数：13200，loss：0.3301069438457489
# 整体测试集上的loss:147.18312710523605
# 整体测试集上的正确率:0.7532
# 模型保存成功
# ------第18轮训练开始------
# 训练次数：13300，loss：0.374763160943985
# 训练次数：13400，loss：0.2727847099304199
# 训练次数：13500，loss：0.23004508018493652
# 训练次数：13600，loss：0.5005054473876953
# 训练次数：13700，loss：0.3860343396663666
# 训练次数：13800，loss：0.35850760340690613
# 训练次数：13900，loss：0.6921489238739014
# 训练次数：14000，loss：0.17140844464302063
# 整体测试集上的loss:174.23155224323273
# 整体测试集上的正确率:0.6914
# 模型保存成功
# ------第19轮训练开始------
# 训练次数：14100，loss：0.23738209903240204
# 训练次数：14200，loss：0.29437148571014404
# 训练次数：14300，loss：0.3281800150871277
# 训练次数：14400，loss：0.24146540462970734
# 训练次数：14500，loss：0.4674316942691803
# 训练次数：14600，loss：0.4389983117580414
# 训练次数：14700，loss：0.3839900493621826
# 训练次数：14800，loss：0.4535958766937256
# 整体测试集上的loss:195.33321470022202
# 整体测试集上的正确率:0.719
# 模型保存成功
# ------第20轮训练开始------
# 训练次数：14900，loss：0.049768391996622086
# 训练次数：15000，loss：0.24034631252288818
# 训练次数：15100，loss：0.3711204528808594
# 训练次数：15200，loss：0.35276082158088684
# 训练次数：15300，loss：0.22125720977783203
# 训练次数：15400，loss：0.20152625441551208
# 训练次数：15500，loss：0.17304018139839172
# 训练次数：15600，loss：0.28800830245018005
# 整体测试集上的loss:137.9921551644802
# 整体测试集上的正确率:0.7758
# 模型保存成功
# ------第21轮训练开始------
# 训练次数：15700，loss：0.11925537139177322
# 训练次数：15800，loss：0.28646525740623474
# 训练次数：15900，loss：0.4032277464866638
# 训练次数：16000，loss：0.32082536816596985
# 训练次数：16100，loss：0.5680587887763977
# 训练次数：16200，loss：0.2546396255493164
# 训练次数：16300，loss：0.28148332238197327
# 训练次数：16400，loss：0.09360473603010178
# 整体测试集上的loss:129.5154853761196
# 整体测试集上的正确率:0.7841
# 模型保存成功
# ------第22轮训练开始------
# 训练次数：16500，loss：0.4907512962818146
# 训练次数：16600，loss：0.19866469502449036
# 训练次数：16700，loss：0.5363712906837463
# 训练次数：16800，loss：0.14218594133853912
# 训练次数：16900，loss：0.18039393424987793
# 训练次数：17000，loss：0.36887791752815247
# 训练次数：17100，loss：0.21772609651088715
# 训练次数：17200，loss：0.19125685095787048
# 整体测试集上的loss:124.02997449040413
# 整体测试集上的正确率:0.7863
# 模型保存成功
# ------第23轮训练开始------
# 训练次数：17300，loss：0.2705797553062439
# 训练次数：17400，loss：0.25842079520225525
# 训练次数：17500，loss：0.15356488525867462
# 训练次数：17600，loss：0.22039008140563965
# 训练次数：17700，loss：0.2161838561296463
# 训练次数：17800，loss：0.18696236610412598
# 训练次数：17900，loss：0.14508305490016937
# 整体测试集上的loss:146.4785297214985
# 整体测试集上的正确率:0.7609
# 模型保存成功
# ------第24轮训练开始------
# 训练次数：18000，loss：0.18114760518074036
# 训练次数：18100，loss：0.34893909096717834
# 训练次数：18200，loss：0.2898176908493042
# 训练次数：18300，loss：0.5926303863525391
# 训练次数：18400，loss：0.3151256740093231
# 训练次数：18500，loss：0.23213952779769897
# 训练次数：18600，loss：0.1564752608537674
# 训练次数：18700，loss：0.2800445854663849
# 整体测试集上的loss:147.36507147550583
# 整体测试集上的正确率:0.7877
# 模型保存成功
# ------第25轮训练开始------
# 训练次数：18800，loss：0.2829516530036926
# 训练次数：18900，loss：0.07808955013751984
# 训练次数：19000，loss：0.09558611363172531
# 训练次数：19100，loss：0.1817176342010498
# 训练次数：19200，loss：0.13569027185440063
# 训练次数：19300，loss：0.34707966446876526
# 训练次数：19400，loss：0.26070865988731384
# 训练次数：19500，loss：0.1935437172651291
# 整体测试集上的loss:138.48578932881355
# 整体测试集上的正确率:0.7688
# 模型保存成功
# ------第26轮训练开始------
# 训练次数：19600，loss：0.841578483581543
# 训练次数：19700，loss：0.12149790674448013
# 训练次数：19800，loss：0.1105538010597229
# 训练次数：19900，loss：0.2222694754600525
# 训练次数：20000，loss：0.11313416063785553
# 训练次数：20100，loss：0.21216297149658203
# 训练次数：20200，loss：0.09265121072530746
# 训练次数：20300，loss：0.1513051688671112
# 整体测试集上的loss:128.57902064919472
# 整体测试集上的正确率:0.7741
# 模型保存成功
# ------第27轮训练开始------
# 训练次数：20400，loss：0.11879968643188477
# 训练次数：20500，loss：0.24491100013256073
# 训练次数：20600，loss：0.0347457230091095
# 训练次数：20700，loss：0.24455571174621582
# 训练次数：20800，loss：0.10446896404027939
# 训练次数：20900，loss：0.11624934524297714
# 训练次数：21000，loss：0.3952534794807434
# 训练次数：21100，loss：0.07645150274038315
# 整体测试集上的loss:136.48235774040222
# 整体测试集上的正确率:0.789
# 模型保存成功
# ------第28轮训练开始------
# 训练次数：21200，loss：0.07429070770740509
# 训练次数：21300，loss：0.1675415188074112
# 训练次数：21400，loss：0.16555668413639069
# 训练次数：21500，loss：0.07335545122623444
# 训练次数：21600，loss：0.0407504141330719
# 训练次数：21700，loss：0.12884509563446045
# 训练次数：21800，loss：0.04036857187747955
# 整体测试集上的loss:182.22198647260666
# 整体测试集上的正确率:0.7289
# 模型保存成功
# ------第29轮训练开始------
# 训练次数：21900，loss：0.1220502108335495
# 训练次数：22000，loss：0.20652365684509277
# 训练次数：22100，loss：0.0986938402056694
# 训练次数：22200，loss：0.09381023794412613
# 训练次数：22300，loss：0.12850411236286163
# 训练次数：22400，loss：0.1924370974302292
# 训练次数：22500，loss：0.22235600650310516
# 训练次数：22600，loss：0.03345222771167755
# 整体测试集上的loss:158.0247246325016
# 整体测试集上的正确率:0.7917
# 模型保存成功
# ------第30轮训练开始------
# 训练次数：22700，loss：0.1052565947175026
# 训练次数：22800，loss：0.10362160205841064
# 训练次数：22900，loss：0.0885201096534729
# 训练次数：23000，loss：0.1805228888988495
# 训练次数：23100，loss：0.06272292137145996
# 训练次数：23200，loss：0.21158285439014435
# 训练次数：23300，loss：0.10624437779188156
# 训练次数：23400，loss：0.1489718109369278
# 整体测试集上的loss:184.62472087144852
# 整体测试集上的正确率:0.7677
# 模型保存成功
